# %% [markdown]
# # Módulo 3: Preprocesamiento
#
# ## Leakage & feature engineering
#
# #### Objetivo
#
# * Definiremos qué es la ingeniería de variables, su utilidad y aplicación en la vida diaria de un data scientist.
# * Aplicaremos a una base sintética un proceso de feature engineering y probaremos la utilidad del concepto.
#
# #### Actividad 1
# * Abordar y comprender tres tipos básicos de _leakage_:
#     * Target
#     * Time
#     * User
#         * Tomar el dataset `user_leakage.csv` de Canvas.
#
# * Abordar y comprender _feature engineering_ para instancias temporalmente dependientes.
#     * Tomar el dataset `feature_eng_time_dependant.csv` de Canvas.
#     * Generar nuevas variables en dos grupos:
#         * Grupos de variables de cambio.
#         * Grupos de rezagos.
#     * Generar un mapa de correlaciones para observar la influencia de las nuevas variables.
# * Abordar y comprender _feature engineering_ para instancias temporalmente independientes pero con repetición de usuarios.
#     * Tomar el dataset `AB_NYC_2019_class.csv` de Canvas.
#     * Generar nuevas variables en dos grupos:
#         * Variables de usuario.
#         * Variables a partir de las existentes.
#     * Generar bivariados para la comparación de éxito de las variables.
#
#
# #### Actividad 2
#
# * Tarea I: Stocks.
#     * Genera al menos 3 propuestas de variables que no hayan sido generadas en clase.
#         * Generar solo más rezagos (por ejemplo 15 en lugar de 7) no será tomado en cuenta.
#     * Calcula las correlaciones de tus variables con la variable de respuesta.
#     * Responde: ¿Tus variables tienen una correlación alta o baja con la respuesta? ¿Por qué crees que pase eso?
# * Tarea II: Airbnb.
#     * Proponer 5 variables nuevas de las cuales:
#         * Dos tienen que tener relación entre usuarios (como el ejemplo de clase). Recuerda que para generarlas a todo el frame puedes usar `shift` y `expanding`.
#         * Cuidar en las 5 temas de feature leakage, sobre todo en el punto anterior.
#     * Generar gráficas de bivariados de tus nuevas variables y hacer análisis al respecto.
#     * Responde: ¿Tus variables muestran una relación adecuada en los bivariados? ¿Por qué crees que pase eso?

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from math import radians, cos, sin, asin, sqrt
from sklearn.metrics import mean_absolute_error, median_absolute_error, roc_auc_score
import re
import time
import os
import sys
import warnings
import pickle

warnings.filterwarnings("ignore")

# %matplotlib inline
plt.style.use('ggplot')

seed = 28
path = '.'

# %% [markdown]
# ###  Leakage
#
# Este fenómeno ocurre cuando nuestro set de entrenamiento contiene información "futura" (generalmente de manera no intencional) o que tiene información en distinta medida de nuestra variable de respuesta.
#
# A manera de regla empírica podemos asumir que si el modelo es demasiado bueno para ser cierto, si el modelo está mostrando un performance productivo mucho menor que el de desarrollo o si hay _overfitting_, podría deberse a este fenómeno.
#
# Algunos de los leakages más comunes:
# * Target.
# * User.
# * Time.
#
#
#
# #### Target leakage
#
# Este tipo de _leakage_ particular es uno muy común y muy fácil de detectar.
#
# _¿En qué consiste?_
#
# En incluir la variable de respuesta o una transformación de la misma en el conjunto de entrenamiento.

# %%
import pandas as pd
precios = [100, 200, 500, 300, 150]
metros_cuadrados = [10, 30, 60, 35, 15]

df = pd.DataFrame()
df['precios'] = precios
df['m2'] = metros_cuadrados
df
# Out:
#    precios  m2
# 0      100  10
# 1      200  30
# 2      500  60
# 3      300  35
# 4      150  15

# %% [markdown]
# Suponga que en el ejemplo anterior usted tiene la variable independiente `m2` y estimará la variable dependiente `precios`.

# %%
# Modelo
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(df[['m2', 'precios']], df['precios'])

# %%
# Predicciones
predicciones = model.predict(df[['m2','precios']])
predicciones
# Out:
# array([100., 200., 500., 300., 150.])

# %% [markdown]
# Haremos una pausa para introducir otra métrica de evaluación de modelos de regresión, el `MAE`.
#
# $$\text{MAE} = \frac{1}{n} \sum_{i=0}^n \vert y_i - \hat{y_i} \vert$$
#
# Mediremos el `MAE`:

# %%
mean_absolute_error(y_true=df['precios'], y_pred=predicciones)
# Out:
# 5.1159076974727215e-14

# %% [markdown]
# Casi cero.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Generemos ahora un modelo sin `precios` como parte de los predictores.

# %%
model2 = LinearRegression().fit(df[['m2']], df['precios'])
predicciones2 = model2.predict(df[['m2']])

# %% [markdown]
# Nuevamente el `MAE`.

# %%
mean_absolute_error(y_pred=predicciones2, y_true=df['precios'])
# Out:
# 20.0

# %% [markdown]
# Observemos coeficientes de ambos modelos

# %%
model.coef_
# Out:
# array([-1.17450262e-15,  1.00000000e+00])

# %%
model2.coef_
# Out:
# array([7.90322581])

# %% [markdown]
# Lo que hicimos en realidad con el primer modelo fue algo así:

# %% [markdown]
# $$\text{precio} =  \beta_0 \times \text{precio} + \beta_1 \times m^2$$
#
# $$\text{precio} =  \text{precio} - 1x10^{-15} \times m^2$$

# %% [markdown]
# Mientras que el segundo modelo fue algo así:

# %% [markdown]
# $$\text{precio} = 7.90 \times m^2$$

# %% [markdown]
# Claramente el modelo con _leakage_ tiene una ventaja: Ya conoce la respuesta. Literalmente está haciendo trampa.

# %% [markdown]
# #### User leakage
#
# El _leakage_ de usuarios se da cuando son pocas las características que se tienen para identificación de usuarios y se usa a un mismo usuario (o a varios) en un _set_ de evaluación y otro de entrenamiento.
#
# Suponga tiene el siguiente set:

# %%
df = pd.read_csv('user_leakage.csv')
df.head()
# Out:
#           x          y
# 0  0.336870  14.716096
# 1  1.514620  62.221753
# 2 -0.967835 -40.887022
# 3  0.446332  -1.873505
# 4 -0.302369 -14.040607

# %% [markdown]
# Vamos a tomar los primeros 8 renglones (80%) para generar un modelo. Después vamos a evaluar su performance usando `MAE` en ese mismo set y en el set que quedó fuera.
#
# Separemos sets:

# %%
train = df.loc[0:7]
test = df.loc[8::]

# %% [markdown]
# Generemos un modelo:

# %%
model = LinearRegression().fit(train[['x']], train[['y']])

# %% [markdown]
# Midamos el error en `train` y en `test`.
#
# Primero en `train`:

# %%
predictions = model.predict(train[['x']])
error = mean_absolute_error(y_pred=predictions, y_true=train['y'])
error
# Out:
# 6.599727144246351

# %% [markdown]
# Ahora en `test`:

# %%
predictions = model.predict(test[['x']])
error = mean_absolute_error(y_pred=predictions, y_true=test['y'])
error
# Out:
# 8.22523418354955

# %% [markdown]
# El error es considerablemente mayor en `test` (~25% mayor) que en `train`.
#
# Esto es de esperarse pues el modelo se entrenó con `train`.
#
# Hagamos el ejercicio de nuevo pero con todos nuestros datos.

# %%
predictions = model.predict(df[['x']])
error = mean_absolute_error(y_pred=predictions, y_true=df['y'])
error
# Out:
# 6.92482855210699

# %% [markdown]
# El error se ubica entre el del `train` y el del `test`.
#
# Esto se debe a que los errores mutuamente se netean y le estamos dando una ventaja injusta en esta evaluación:
#
# * Lo estamos evaluando con usuarios que ya conoció y de los que ya aprendió.

# %% [markdown]
# #### Time leakage
#
# Uno de los más comunes entre la comunidad de _data science_, se trata de la incorporación de información futura sin tener en cuenta el cambio en el tiempo.
#
# Tomemos en cuenta el siguiente flujo de predicción.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Al incorporar en el modelo la variable "tiempo de duración de la autopsia" incurrimos en _time leakage_ o _future leakage_ :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Generamos una referencia circular, el modelo tendrá un performance excelente pero irreal.

# %% [markdown]
# ###  Feature engineering
#
# El proceso de ingeniería de variables consiste en generar nuevas variables a partir de las existentes y/o nuevas fuentes de información.
#
#
# Para poder generar nuevas variables es **de vital importancia** tener en cuenta el _leakage_.
#
#
# Supongamos el caso de _Netflix_ (recomendación de series/películas). Algunas preguntas guía que nos podemos hacer son:
#
# * ¿Qué me preguntaría a mí mismo para darle pistas a Netflix de lo que me gusta ver?
# * ¿Qué influye en mi comportamiento que puede determinar mi siguiente paso?
# * ¿Cómo puedo generar información ortogonal  en mi _dataset_ a partir de lo que ya tengo?
#
#
# #### Feature engineering w/stocks: Netflix case
#
# Empezaremos con la estimación de precios reportados en Y!Finance. Para la descarga de información se utilizó: https://pypi.org/project/yfinance/.

# %%
df = pd.read_csv('feature_eng_time_dependant.csv', index_col=0)
df
# Out:
#                   open        high         low       close
# Date
# 2020-01-02  326.100006  329.980011  324.779999  329.809998
# 2020-01-03  326.779999  329.859985  325.529999  325.899994
# 2020-01-06  323.119995  336.359985  321.200012  335.829987
# 2020-01-07  336.470001  336.700012  330.299988  330.750000
# 2020-01-08  331.489990  342.700012  331.049988  339.260010
# ...                ...         ...         ...         ...
# 2022-01-24  383.910004  387.260010  351.459991  387.149994
# 2022-01-25  379.140015  387.709991  365.130005  366.420013
# 2022-01-26  378.269989  382.660004  356.619995  359.700012
# 2022-01-27  382.059998  394.799988  378.100006  386.700012
# 2022-01-28  386.760010  387.000000  372.079987  384.359985
#
# [524 rows x 4 columns]

# %% [markdown]
# Si no tenemos otro tipo de información más que el precio, ¿qué podemos utilizar?
#
# * ¿Cómo inició el precio ese día?
# * ¿Cómo cerró el precio ese día?
# * ¿Cuál fue el más alto del día?
# * ¿Cuál fue el más bajo del día?
#
# En lugar de eliminar todas esas columnas, las aprovecharemos a manera de features independientes (aunque temporalmente dependan unos de otros).
#
#
# ##### ¿Qué más?
#
# Esos datos ya son provistos por la API, ¿qué tal si intentamos replicar ese comportamiento a lo largo del tiempo?

# %% [markdown]
# ##### Acomodando precios
#
# No podemos considerar el precio del día de hoy para estimar el precio del día de hoy.
#
#
# **Disclaimer: Se asume que el modelo correrá en las mañanas tal que se puede saber el precio de cierre del día anterior.**

# %%
df.head()
# Out:
#                   open        high         low       close
# Date
# 2020-01-02  326.100006  329.980011  324.779999  329.809998
# 2020-01-03  326.779999  329.859985  325.529999  325.899994
# 2020-01-06  323.119995  336.359985  321.200012  335.829987
# 2020-01-07  336.470001  336.700012  330.299988  330.750000
# 2020-01-08  331.489990  342.700012  331.049988  339.260010

# %%
# Lagging our frame
response = 'close_today'
lag_1 = df.shift(1).dropna()

# Adding response
lag_1 = pd.merge(lag_1,df['close'], 
                 left_index = True, right_index = True,
                 suffixes=('_yday', '_today'))
lag_1
# Out:
#                   open        high         low  close_yday  close_today
# Date
# 2020-01-03  326.100006  329.980011  324.779999  329.809998   325.899994
# 2020-01-06  326.779999  329.859985  325.529999  325.899994   335.829987
# 2020-01-07  323.119995  336.359985  321.200012  335.829987   330.750000
# 2020-01-08  336.470001  336.700012  330.299988  330.750000   339.260010
# 2020-01-09  331.489990  342.700012  331.049988  339.260010   335.660004
# ...                ...         ...         ...         ...          ...
# 2022-01-24  400.429993  409.149994  379.989990  397.500000   387.149994
# 2022-01-25  383.910004  387.260010  351.459991  387.149994   366.420013
# 2022-01-26  379.140015  387.709991  365.130005  366.420013   359.700012
# 2022-01-27  378.269989  382.660004  356.619995  359.700012   386.700012
# 2022-01-28  382.059998  394.799988  378.100006  386.700012   384.359985
#
# [523 rows x 5 columns]

# %% [markdown]
# Info del 2 de enero se pasa a ser la predictora del día 3:
# <img src="leakage_from_yesterday.png">

# %% [markdown]
# La respuesta (el precio de cierre) del día 3 se mantiene y la info de ayer (2 de enero) se elimina.
#
# <img src="leakage_from_yesterday2.png">

# %% [markdown]
# Con esto tenemos que:
# * `close_tday` es el precio de cierre del día en cuestión (el del índice).
# * `close_yday` es el precio de cirre del día anterior. En el renglón del 3 de enero, este valor será el del 2 de enero.
# * Todos los demás datos corresponden a los datos del día anterior.
#
# **No olvides el leakage.**

# %% [markdown]
# ##### Delta de precios
#
# $$ \Delta y_t = y_{t-1} - y_{\text{open}, t-1}  $$
#
#
# ##### Cambio (delta) relativo de precios
#
# $$ \Delta_{rel} y_t = \frac{y_{t-1}}{y_{\text{open}, t-1}} - 1   $$

# %%
# Delta
lag_1['delta_open'] = lag_1['close_yday'] - lag_1['open']

# Deltarel
lag_1['delta_rel_open'] = lag_1['close_yday'] / lag_1['open'] - 1 

lag_1
# Out:
#                   open        high         low  close_yday  close_today  \
# Date
# 2020-01-03  326.100006  329.980011  324.779999  329.809998   325.899994
# 2020-01-06  326.779999  329.859985  325.529999  325.899994   335.829987
# 2020-01-07  323.119995  336.359985  321.200012  335.829987   330.750000
# 2020-01-08  336.470001  336.700012  330.299988  330.750000   339.260010
# 2020-01-09  331.489990  342.700012  331.049988  339.260010   335.660004
# ...                ...         ...         ...         ...          ...
# 2022-01-24  400.429993  409.149994  379.989990  397.500000   387.149994
# 2022-01-25  383.910004  387.260010  351.459991  387.149994   366.420013
# 2022-01-26  379.140015  387.709991  365.130005  366.420013   359.700012
# 2022-01-27  378.269989  382.660004  356.619995  359.700012   386.700012
# 2022-01-28  382.059998  394.799988  378.100006  386.700012   384.359985
#
#             delta_open  delta_rel_open
# Date
# 2020-01-03    3.709991        0.011377
# 2020-01-06   -0.880005       -0.002693
# 2020-01-07   12.709991        0.039335
# 2020-01-08   -5.720001       -0.017000
# 2020-01-09    7.770020        0.023440
# ...                ...             ...
# 2022-01-24   -2.929993       -0.007317
# 2022-01-25    3.239990        0.008439
# 2022-01-26  -12.720001       -0.033550
# 2022-01-27  -18.569977       -0.049092
# 2022-01-28    4.640015        0.012145
#
# [523 rows x 7 columns]

# %% [markdown]
# Podemos hacer lo mismo con high y low, por lo que para evitar la fatiga de codear generaremos una función.

# %%
def delta_values(data: pd.DataFrame, first:str, second: str, relative: bool):

    if relative:
        print(f'--> Dividing {first} by {second}.')
        return data[first] / data[second] - 1

    print(f'--> Getting {first} by {second}.')
    return data[first] - data[second]

# %% [markdown]
# Comprobando que sirva.

# %%
lag_1.head(1)
# Out:
#                   open        high         low  close_yday  close_today  \
# Date
# 2020-01-03  326.100006  329.980011  324.779999  329.809998   325.899994
#
#             delta_open  delta_rel_open
# Date
# 2020-01-03    3.709991        0.011377

# %%
columns = ['high', 'low']

for col in columns:
    lag_1[f'delta_{col}'] = delta_values(lag_1, 'close_yday', col, False).values
    lag_1[f'delta_rel_{col}'] = delta_values(lag_1, 'close_yday', col, True).values
# Out:
# --> Getting close_yday by high.
# --> Dividing close_yday by high.
# --> Getting close_yday by low.
# --> Dividing close_yday by low.

# %%
lag_1.head(2)
# Out:
#                   open        high         low  close_yday  close_today  \
# Date
# 2020-01-03  326.100006  329.980011  324.779999  329.809998   325.899994
# 2020-01-06  326.779999  329.859985  325.529999  325.899994   335.829987
#
#             delta_open  delta_rel_open  delta_high  delta_rel_high  delta_low  \
# Date
# 2020-01-03    3.709991        0.011377   -0.170013       -0.000515   5.029999
# 2020-01-06   -0.880005       -0.002693   -3.959991       -0.012005   0.369995
#
#             delta_rel_low
# Date
# 2020-01-03       0.015487
# 2020-01-06       0.001137

# %% [markdown]
# #### Uso del histórico
# En clases anteriores ya habíamos utilizado los famosos rezagos, generemos al menos un rezago de una semana.

# %%
lags = 7 

for lag in range(2, lags + 1):
    lag_1[f'lag_{lag}'] = lag_1.close_today.shift(lag)

# %%
lag_1.head(lags * 2)
# Out:
#                   open        high         low  close_yday  close_today  \
# Date
# 2020-01-03  326.100006  329.980011  324.779999  329.809998   325.899994
# 2020-01-06  326.779999  329.859985  325.529999  325.899994   335.829987
# 2020-01-07  323.119995  336.359985  321.200012  335.829987   330.750000
# 2020-01-08  336.470001  336.700012  330.299988  330.750000   339.260010
# 2020-01-09  331.489990  342.700012  331.049988  339.260010   335.660004
# 2020-01-10  342.000000  343.420013  334.609985  335.660004   329.049988
# 2020-01-13  337.130005  338.500000  327.269989  329.049988   338.920013
# 2020-01-14  331.799988  340.850006  331.510010  338.920013   338.690002
# 2020-01-15  344.399994  345.380005  335.519989  338.690002   339.070007
# 2020-01-16  338.679993  343.170013  336.600006  339.070007   338.619995
# 2020-01-17  343.500000  343.559998  335.850006  338.619995   339.670013
# 2020-01-21  341.000000  341.570007  337.380005  339.670013   338.109985
# 2020-01-22  340.000000  341.000000  332.589996  338.109985   326.000000
# 2020-01-23  332.549988  336.299988  323.600006  326.000000   349.600006
#
#             delta_open  delta_rel_open  delta_high  delta_rel_high  delta_low  \
# Date
# 2020-01-03    3.709991        0.011377   -0.170013       -0.000515   5.029999
# 2020-01-06   -0.880005       -0.002693   -3.959991       -0.012005   0.369995
# 2020-01-07   12.709991        0.039335   -0.529999       -0.001576  14.629974
# 2020-01-08   -5.720001       -0.017000   -5.950012       -0.017672   0.450012
# 2020-01-09    7.770020        0.023440   -3.440002       -0.010038   8.210022
# 2020-01-10   -6.339996       -0.018538   -7.760010       -0.022596   1.050018
# 2020-01-13   -8.080017       -0.023967   -9.450012       -0.027917   1.779999
# 2020-01-14    7.120026        0.021459   -1.929993       -0.005662   7.410004
# 2020-01-15   -5.709991       -0.016580   -6.690002       -0.019370   3.170013
# 2020-01-16    0.390015        0.001152   -4.100006       -0.011947   2.470001
# 2020-01-17   -4.880005       -0.014207   -4.940002       -0.014379   2.769989
# 2020-01-21   -1.329987       -0.003900   -1.899994       -0.005563   2.290009
# 2020-01-22   -1.890015       -0.005559   -2.890015       -0.008475   5.519989
# 2020-01-23   -6.549988       -0.019696  -10.299988       -0.030627   2.399994
#
#             delta_rel_low       lag_2       lag_3       lag_4       lag_5  \
# Date
# 2020-01-03       0.015487         NaN         NaN         NaN         NaN
# 2020-01-06       0.001137         NaN         NaN         NaN         NaN
# 2020-01-07       0.045548  325.899994         NaN         NaN         NaN
# 2020-01-08       0.001362  335.829987  325.899994         NaN         NaN
# 2020-01-09       0.024800  330.750000  335.829987  325.899994         NaN
# 2020-01-10       0.003138  339.260010  330.750000  335.829987  325.899994
# 2020-01-13       0.005439  335.660004  339.260010  330.750000  335.829987
# 2020-01-14       0.022352  329.049988  335.660004  339.260010  330.750000
# 2020-01-15       0.009448  338.920013  329.049988  335.660004  339.260010
# 2020-01-16       0.007338  338.690002  338.920013  329.049988  335.660004
# 2020-01-17       0.008248  339.070007  338.690002  338.920013  329.049988
# 2020-01-21       0.006788  338.619995  339.070007  338.690002  338.920013
# 2020-01-22       0.016597  339.670013  338.619995  339.070007  338.690002
# 2020-01-23       0.007417  338.109985  339.670013  338.619995  339.070007
#
#                  lag_6       lag_7
# Date
# 2020-01-03         NaN         NaN
# 2020-01-06         NaN         NaN
# 2020-01-07         NaN         NaN
# 2020-01-08         NaN         NaN
# 2020-01-09         NaN         NaN
# 2020-01-10         NaN         NaN
# 2020-01-13  325.899994         NaN
# 2020-01-14  335.829987  325.899994
# 2020-01-15  330.750000  335.829987
# 2020-01-16  339.260010  330.750000
# 2020-01-17  335.660004  339.260010
# 2020-01-21  329.049988  335.660004
# 2020-01-22  338.920013  329.049988
# 2020-01-23  338.690002  338.920013

# %% [markdown]
# #### Mapa de correlaciones
#
# La correlación se define como:
#
# $$ \rho = \frac{\text{cov}(X, Y)}{\sigma_x\sigma_y}$$

# %%
corr = lag_1.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_78f65_row0_col0, #T_78f65_row0_col1, #T_78f65_row0_col2, #T_78f65_row0_col11, #T_78f65_row1_col0, #T_78f65_row1_col1, #T_78f65_row1_col2, #T_78f65_row1_col3, #T_78f65_row2_col0, #T_78f65_row2_col1, #T_78f65_row2_col2, #T_78f65_row2_col3, #T_78f65_row3_col1, #T_78f65_row3_col2, #T_78f65_row3_col3, #T_78f65_row4_col4, #T_78f65_row5_col5, #T_78f65_row6_col6, #T_78f65_row7_col7, #T_78f65_row8_col8, #T_78f65_row9_col9, #T_78f65_row10_col10, #T_78f65_row11_col0, #T_78f65_row11_col11, #T_78f65_row12_col12, #T_78f65_row13_col13, #T_78f65_row14_col14, #T_78f65_row15_col15, #T_78f65_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_78f65_row0_col3, #T_78f65_row1_col11, #T_78f65_row2_col11, #T_78f65_row3_col0, #T_78f65_row11_col1, #T_78f65_row11_col2 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_78f65_row0_col4, #T_78f65_row0_col12, #T_78f65_row1_col4, #T_78f65_row4_col0, #T_78f65_row4_col1, #T_78f65_row5_col6, #T_78f65_row6_col5, #T_78f65_row12_col0 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_78f65_row0_col5, #T_78f65_row0_col6, #T_78f65_row0_col10, #T_78f65_row15_col7 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_78f65_row0_col7, #T_78f65_row10_col0, #T_78f65_row10_col1, #T_78f65_row10_col2, #T_78f65_row10_col3, #T_78f65_row10_col4, #T_78f65_row10_col11, #T_78f65_row10_col12, #T_78f65_row10_col13, #T_78f65_row10_col14, #T_78f65_row10_col15, #T_78f65_row10_col16, #T_78f65_row11_col5, #T_78f65_row11_col6, #T_78f65_row11_col7, #T_78f65_row11_col9, #T_78f65_row11_col10, #T_78f65_row15_col5, #T_78f65_row15_col6, #T_78f65_row15_col8, #T_78f65_row16_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_78f65_row0_col8, #T_78f65_row12_col5, #T_78f65_row12_col7, #T_78f65_row13_col5, #T_78f65_row13_col6, #T_78f65_row13_col7, #T_78f65_row16_col9 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_78f65_row0_col9, #T_78f65_row1_col7, #T_78f65_row2_col10, #T_78f65_row11_col8, #T_78f65_row16_col5, #T_78f65_row16_col6, #T_78f65_row16_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_78f65_row0_col13, #T_78f65_row13_col0 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_78f65_row0_col14, #T_78f65_row1_col14, #T_78f65_row9_col10, #T_78f65_row12_col16, #T_78f65_row14_col1, #T_78f65_row14_col2, #T_78f65_row16_col12 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_78f65_row0_col15, #T_78f65_row1_col15, #T_78f65_row10_col9 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_78f65_row0_col16, #T_78f65_row1_col16, #T_78f65_row4_col14, #T_78f65_row14_col4, #T_78f65_row15_col3, #T_78f65_row16_col0 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_78f65_row1_col5, #T_78f65_row1_col6, #T_78f65_row2_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_78f65_row1_col8, #T_78f65_row12_col6, #T_78f65_row14_col5, #T_78f65_row14_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_78f65_row1_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_78f65_row1_col10 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_78f65_row1_col12, #T_78f65_row2_col12, #T_78f65_row3_col12, #T_78f65_row4_col11, #T_78f65_row11_col4, #T_78f65_row11_col13, #T_78f65_row12_col1, #T_78f65_row12_col2, #T_78f65_row12_col3, #T_78f65_row12_col14, #T_78f65_row13_col11, #T_78f65_row13_col15, #T_78f65_row14_col12, #T_78f65_row14_col16, #T_78f65_row15_col13, #T_78f65_row16_col14 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_78f65_row1_col13, #T_78f65_row2_col13, #T_78f65_row13_col1, #T_78f65_row13_col2, #T_78f65_row13_col16, #T_78f65_row14_col11, #T_78f65_row16_col13 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_78f65_row2_col4, #T_78f65_row3_col4, #T_78f65_row3_col11, #T_78f65_row4_col2, #T_78f65_row4_col3, #T_78f65_row11_col3, #T_78f65_row11_col12, #T_78f65_row12_col11, #T_78f65_row12_col13, #T_78f65_row13_col12, #T_78f65_row13_col14, #T_78f65_row14_col13, #T_78f65_row14_col15, #T_78f65_row15_col14, #T_78f65_row15_col16, #T_78f65_row16_col15 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_78f65_row2_col6, #T_78f65_row2_col7 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_78f65_row2_col8, #T_78f65_row4_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_78f65_row2_col9, #T_78f65_row14_col7, #T_78f65_row14_col8, #T_78f65_row15_col9 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_78f65_row2_col14, #T_78f65_row3_col14, #T_78f65_row4_col13, #T_78f65_row8_col7, #T_78f65_row11_col15, #T_78f65_row13_col4, #T_78f65_row14_col3, #T_78f65_row15_col0, #T_78f65_row15_col11 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_78f65_row2_col15, #T_78f65_row3_col15, #T_78f65_row7_col8, #T_78f65_row11_col16, #T_78f65_row15_col1, #T_78f65_row15_col2, #T_78f65_row16_col11 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_78f65_row2_col16, #T_78f65_row3_col16, #T_78f65_row16_col1, #T_78f65_row16_col2 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_78f65_row3_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_78f65_row3_col6, #T_78f65_row3_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_78f65_row3_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_78f65_row3_col9 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_78f65_row3_col10 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_78f65_row3_col13, #T_78f65_row4_col12, #T_78f65_row11_col14, #T_78f65_row12_col4, #T_78f65_row12_col15, #T_78f65_row13_col3, #T_78f65_row14_col0, #T_78f65_row15_col12 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_78f65_row4_col5, #T_78f65_row5_col12, #T_78f65_row5_col14, #T_78f65_row5_col16, #T_78f65_row6_col12, #T_78f65_row6_col13 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_78f65_row4_col6, #T_78f65_row6_col14, #T_78f65_row6_col16 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_78f65_row4_col8, #T_78f65_row5_col15, #T_78f65_row6_col15 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_78f65_row4_col9 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_78f65_row4_col10 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_78f65_row4_col15, #T_78f65_row15_col4, #T_78f65_row16_col3 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_78f65_row4_col16, #T_78f65_row16_col4 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_78f65_row5_col0, #T_78f65_row5_col11 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_78f65_row5_col1, #T_78f65_row7_col15, #T_78f65_row7_col16 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_78f65_row5_col2, #T_78f65_row9_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_78f65_row5_col3, #T_78f65_row6_col4, #T_78f65_row7_col3, #T_78f65_row9_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_78f65_row5_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_78f65_row5_col7, #T_78f65_row6_col9 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_78f65_row5_col8 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_78f65_row5_col9, #T_78f65_row5_col10, #T_78f65_row10_col6 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_78f65_row5_col13 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_78f65_row6_col0, #T_78f65_row6_col11, #T_78f65_row7_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_78f65_row6_col1, #T_78f65_row7_col14 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_78f65_row6_col2, #T_78f65_row9_col11, #T_78f65_row9_col12 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_78f65_row6_col3, #T_78f65_row9_col13, #T_78f65_row9_col14 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_78f65_row6_col7 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_78f65_row6_col8 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_78f65_row6_col10 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_78f65_row7_col0, #T_78f65_row9_col15, #T_78f65_row9_col16 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_78f65_row7_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_78f65_row7_col4, #T_78f65_row9_col1, #T_78f65_row9_col4 {
#   background-color: #7093f3;
#   color

# %% [markdown]
# Observamos que esta serie en particular tiene una alta relación los _lags_, sin embargo observamos que dos de las variables nuevas (deltas del precio máximo del día anterior y del precio bajo del día anterior) tienen correlaciones interesantes con la variable target.

# %% [markdown]
# #### Feature engineering w/independent instances: Airbnb case

# %%
file_name = 'AB_NYC_2019_class.csv'
df = pd.read_csv(os.path.join(path, file_name))
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name  neighbourhood_group  latitude  longitude  room_type  \
# 0         John                    0  40.64749  -73.97237          0
# 1     Jennifer                    1  40.75362  -73.98377          1
# 2    Elisabeth                    1  40.80902  -73.94190          0
# 3  LisaRoxanne                    0  40.68514  -73.95976          1
# 4        Laura                    1  40.79851  -73.94399          1
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               1                  9  2018-10-19               0.21
# 1               1                 45  2019-05-21               0.38
# 2               3                  0         NaN                NaN
# 3               1                270  2019-07-05               4.64
# 4              10                  9  2018-11-19               0.10
#
#    availability_365  binary_price
# 0               365             0
# 1               355             1
# 2               365             0
# 3               194             0
# 4                 0             0

# %% [markdown]
# ##### Uso de datos geográficos
#
# Un punto de referencia clásico en NYC es Times Square. Nuestra data tiene una base sobre la geografía de la mencionada ciudad, veamos cómo se ve nuestro dataset en el mapa separado por zona.

# %%
# Definiendo Times Square
# TS
times_square = pd.DataFrame({'latitude': 40.758896,
                             'longitude': -73.985130,
                             'neighbourhood_group': 'Times Square'},
                            index=[0]) 
geo_ts = gpd.GeoDataFrame(times_square,
                          geometry=gpd.points_from_xy(times_square.longitude,
                                                      times_square.latitude))
geo_ts
# Out:
#     latitude  longitude neighbourhood_group                   geometry
# 0  40.758896  -73.98513        Times Square  POINT (-73.98513 40.7589)

# %%
# Visualization: ¿Cómo se ven nuestros datos?
# Visualization
replacers = {'neighbourhood_group': {0: 'Brooklyn',
  1: 'Manhattan',
  2: 'Queens',
  3: 'Staten Island',
  4: 'Bronx'}}

gdf = gpd.GeoDataFrame(df.replace(replacers),
                       geometry=gpd.points_from_xy(df.longitude, df.latitude))
gdf = gdf.set_crs('EPSG:4326')

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,10))

gdf.plot(categorical = True,
         column = 'neighbourhood_group',
         legend = True,
         ax=ax[0],
         cmap='nipy_spectral',
         alpha=0.4)

geo_ts.plot(color='yellow',
            marker = '*',
            label='Times square',
            markersize=300,
            legend = True,
            ax=ax[0])

gdf.plot(categorical=True,
         column='binary_price',
         ax=ax[1],
         legend = True,
         alpha = 0.4,
         cmap='Reds')

geo_ts.plot(color='yellow',
            marker='*',
            label='Times square',
            markersize=300,
            legend=True,
            ax=ax[1])
fig.suptitle('NYC AirBnb prices by neigh', fontsize=25)
ax[0].set_title('NYC groups', fontsize=15)
ax[1].set_title('Binary price per location')
fig.tight_layout()
plt.show()

# %% [markdown]
# Confirmamos lo que en teoría tenía sentido: Cercanía a puntos turísticos (en este caso _Times Square_) influye en el precio de renta de inmuebles.
#
# Definamos otras ideas, la pregunta central aquí es:
#
# ¿Qué puede influir en el precio del Airbnb? ¿Qué se puede calcular?
#
# Veamos nuevamente la información:

# %% [markdown]
# ### Definiendo ideas
# Definamos algunas ideas de variables que podemos sacar:
#
# * Distancia a TS.
# * Número de reviews **que tiene un host.**
# * Cantidad de caracteres en la descripción.
# * Cantidad de habitaciones/baños mencionados.

# %% [markdown]
# #### Establezcamos una forma de obtener features agrupados
#
# El goal aquí es obtener estadísticos de un usuario.

# %%
host_ejemplo = 2787

# %%
df.loc[df.host_id == host_ejemplo, ['name', 'number_of_reviews', 'host_name', 'last_review']]
# Out:
#                                                     name  number_of_reviews  \
# 0                     Clean & quiet apt home by the park                  9
# 10372  Riomaggiore Room. Queen Bedroom in Bklyn Townh...                 21
# 13583                               Torre del Lago Room.                 17
# 13688  Cinque Terre Room.  Clean and Quiet Queen Bedroom                 24
# 13963  La Spezia room.  Clean, quiet and comfortable bed                 15
# 21556   Brooklyn home.  Comfort and clean. Liguria room.                 19
#
#       host_name last_review
# 0          John  2018-10-19
# 10372      John  2018-10-27
# 13583      John  2019-06-26
# 13688      John  2019-05-11
# 13963      John  2018-09-29
# 21556      John  2019-06-08

# %%
example_host = df.loc[df.host_id == host_ejemplo].copy()

# %% [markdown]
# Supongamos que queremos contar los reviews acumuladas de un user.
#
# Esto nos va a permitir:
#
# * Para usuarios nuevos
#     * Entender si un host nuevo tiene precios más altos / bajos que un usuario cotizado (con experiencia).
# * Para usuarios recurrentes
#     * Entender cómo va cambiando la relación del precio una vez que el usuario genera clientes y experiencia en la empresa.
#
#
# Un componente fundamental en el análisis de data leakage es el tiempo, pues es el ordenamiento primario que nosotros tenemos para identificar eventos.
#
# Como en este dataset no tenemos el tiempo, usaremos el `id` como nuestro componente ordenador asumiendo que una instancia (renglón) de nuestro set con `id=1` sucedió primero que una con `id=2`.

# %% [markdown]
# Esto significa que no podemos hacer un simple:

# %%
example_host.groupby('host_id').agg({'number_of_reviews': 'sum'})
# Out:
#          number_of_reviews
# host_id
# 2787                   105

# %% [markdown]
# Porque estaríamos agrupando todos los inmuebles sin importar su ocurrencia temporal. La estrategia irá más o menos así:
#
# * Identificar a un usuario.
# * Recorrer sus valores y hacer operaciones en ellos.
# * Agregar.
#
# Comenzaremos trabajando en un único usuario y sobre la misma variable: Reviews acumuladas **hasta antes del inmueble actual**.

# %%
example_host = example_host[['number_of_reviews']].reset_index()
example_host
# Out:
#    index  number_of_reviews
# 0      0                  9
# 1  10372                 21
# 2  13583                 17
# 3  13688                 24
# 4  13963                 15
# 5  21556                 19

# %%
example_host.sort_index().shift(1).expanding().mean()
# Out:
#       index  number_of_reviews
# 0       NaN                NaN
# 1      0.00           9.000000
# 2   5186.00          15.000000
# 3   7985.00          15.666667
# 4   9410.75          17.750000
# 5  10321.20          17.200000

# %%
example_host.sort_index()['number_of_reviews'].shift(1).cumsum().fillna(0)
# Out:
# 0     0.0
# 1     9.0
# 2    30.0
# 3    47.0
# 4    71.0
# 5    86.0
# Name: number_of_reviews, dtype: float64

# %% [markdown]
# En este caso fue muy sencillo pues solo hicimos una suma acumulada con lag. ¿Qué hubiera pasado si quisieramos calcular la misma variable pero promedio?

# %% [markdown]
# Nuestros viejos amigos `shift`, `expanding` y la función agregadora nuevamente salvando el día.
#
# Ahora con esta nueva columna podemos tener un **análisis de usuario** sin agregar el leakage que haría normalmente un `groupby`seguido de un `aggregate`.
#
# El paso posterior sería hacerlo para todo el frame, es decir, hacer una agrupación por usuario y con ayuda de `apply`, `lambda` y las herramientas aquí propuestas agregarla todo el frame.

# %% [markdown]
# #### Otros ejemplos de features que podemos calcular:
#
# ##### Longitud del nombre

# %%
df['longitud_nombre'] = df.name.apply(lambda x: len(str(x)))

# %%
df[['name','longitud_nombre', 'binary_price']].head()
# Out:
#                                                name  longitud_nombre  \
# 0                Clean & quiet apt home by the park               34
# 1                             Skylit Midtown Castle               21
# 2               THE VILLAGE OF HARLEM....NEW YORK !               35
# 3                   Cozy Entire Floor of Brownstone               31
# 4  Entire Apt: Spacious Studio/Loft by central park               48
#
#    binary_price
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0

# %% [markdown]
# Veamos qué hizo

# %%
df['bin_longitud_nombre'] = pd.qcut(df.longitud_nombre, 5)

# %%
df.groupby('bin_longitud_nombre')['binary_price'].mean().plot(marker='o')
# Out:
# <Axes: xlabel='bin_longitud_nombre'>

# %% [markdown]
# ##### Baños presentes en la descripción

# %%
df['bath_present'] = df.name.apply(
    lambda x: 1
    if isinstance(x, str)
    and 'bath' in x.lower()
    else 0
)

# %%
df.groupby('bath_present')['binary_price'].mean()
# Out:
# bath_present
# 0    0.302490
# 1    0.347299
# Name: binary_price, dtype: float64

# %% [markdown]
# Veamos qué hizo

# %% [markdown]
# Moraleja: Feature engineering es algo **fundamental** pues nos permite entre otras cosas extraer patrones "ocultos" en nuestro dataset que puede que el modelo no encuentre (o le sea muy complicado).

# %% [markdown]
# ### Separando sets para evitar user leakage
#
# Típicamente en todas las competencias/papers se acostumbra separar en diferentes conjuntos como:
#
# * Train.
# * Test.
# * OOS.
# * OOT.
#
# La separación de sets por usuarios es una práctica extra y recomendada en sets que comparten usuarios.

# %%
df.host_id.duplicated().sum()
# Out:
# np.int64(11438)

# %% [markdown]
# Tenemos algunos duplicados, para evitar de manera correcta el feature leakage hay que separar usuarios que nos van a servir para entrenar y usuarios para poder evaluar. Esto tiene relación con el punto de "leakage de usuario".
#
# Mantengamos una proporción 80/20 **de usuarios.**

# %%
usuarios_unicos = df.host_id.unique().tolist()
len(usuarios_unicos)
# Out:
# 37457

# %%
host_df = pd.DataFrame(df['host_id'].unique())
#host_df
# Out:
#                0
# 0           2787
# 1           2845
# 2           4632
# 3           4869
# 4           7192
# ...          ...
# 37452  274307600
# 37453  274311461
# 37454  274321313
# 37455   23492952
# 37456   68119814
#
# [37457 rows x 1 columns]

# %%
# Separacion aleatoria de sets 
train, test = train_test_split(host_df, test_size=.2)

# %%
train.shape, test.shape, host_df.shape
# Out:
# ((29965, 1), (7492, 1), (37457, 1))

# %%
# Separemos en host para entrenar y para testear
host_entrenamiento = [c[0] for c in train.values.tolist()]
host_test = [c[0] for c in test.values.tolist()]

# %% [markdown]
# Necesitamos asegurarnos que un host de entrenamiento no va a aparecer en `test_hosts`.

# %%
# Comprobemos que no hay intersección
training_host = df.loc[df.host_id.isin(host_entrenamiento)]
test_host = df.loc[df.host_id.isin(host_test)]


training_host.shape, test_host.shape, df.shape

# %% [markdown]
# Con esto ya creamos nuestros data sets para entrenar y para probar con nuestros usuarios previamente seleccionados.
#
# La idea de hacer esto es poder tener un dataset del cual generaremos features de usuario evitando dos posibles leakages:
#
# * De usuario al calcular features nivel usuario sin que haya intersección.
# * De tiempo al evitar que haya información futura contenida en instancias de entrenamiento.
